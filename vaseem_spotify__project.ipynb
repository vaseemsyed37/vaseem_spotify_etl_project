# %%
 # !pip install spotipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 12.6 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="c55facf47e3a4d03b5cedc9600c1447e", client_secret="494dcec647a049aca7182f6a169aa0e9")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/6CoMFtT345JRz1AtYZshF4"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2024-11-08T06:53:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/robdink1fu7au2uyuo8aum3ao'},
#    'href': 'https://api.spotify.com/v1/users/robdink1fu7au2uyuo8aum3ao',
#    'id': 'robdink1fu7au2uyuo8aum3ao',
#    'type': 'user',
#    'uri': 'spotify:user:robdink1fu7au2uyuo8aum3ao'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '66sgvYGlzFD9QyMzHYFqRh'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Open Letter'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-02-18'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 15

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/66sgvYGlzFD9QyMzHYFqRh'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '66sgvYGlzFD9QyMzHYFqRh',
#   'name': 'Open Letter',
#   'release_date': '2023-02-18',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/66sgvYGlzFD9QyMzHYFqRh'},
#  {'album_id': '1rbTFWa6pVztLGlJzW0ABx',
#   'name': 'Gumaan',
#   'release_date': '2020-09-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1rbTFWa6pVztLGlJzW0ABx'},
#  {'album_id': '7bzGEQUHmMZOcz0DQdecAO',
#   'name': 'Anjaan',
#   'release_date': '2021-09-03',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7bzGEQUHmMZOcz0DQdecAO'},
#  {'album_id': '49SibiaazOamj2Pf2bi0dA',
#   'name': 'Since Tum',
#   'release_date': '2024-09-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/49SibiaazOamj2Pf2bi0dA'},
#  {'album_id': '6gQbhFLkMM1b0dcYPz4PLL',
#   'name': 'Jawab De',
#   'release_date': '2024-10-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6gQbhFLkMM1b0dcYPz4PLL'},
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-11-08T06:53:56Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/robdink1fu7au2uyuo8aum3ao'},
#   'href': 'https://api.spotify.com/v1/users/robdink1fu7au2uyuo8aum3ao',
#   'id': 'robdink1fu7au2uyuo8aum3ao',
#   'type': 'user',
#   'uri': 'spotify:user:robdink1fu7au2uyuo8aum3ao'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '69xcFpmqTOmFNOL08Bxyci',
#   'artist_name': 'Talha Anjum',
#   'external_url': 'https://api.spotify.com/v1/artists/69xcFpmqTOmFNOL08Bxyci'},
#  {'artist_id': '1n6pjRJkTY5v8RtUCAv5pi',
#   'artist_name': 'Umair',
#   'external_url': 'https://api.spotify.com/v1/artists/1n6pjRJkTY5v8RtUCAv5pi'},
#  {'artist_id': '01PyusFVbXgoD5Kl1mR8CC',
#   'artist_name': 'Young Stunners',
#   'external_url': 'https://api.spotify.com/v1/artists/01PyusFVbXgoD5Kl1mR8CC'},
#  {'artist_id': '69xcFpmqTOmFNOL08Bxyci',
#   'artist_name': 'Talha Anjum',
#   'external_url': 'https://api.spotify.com/v1/artists/69xcFpmqTOmFNOL08Bxyci'},
#  {'artist_id': '3mGW1eoqwNtCxd8R3hIOM5',
#   'artist_name': 'Talhah Yunus',
#   'external_url': 'https://api.spotify.com/v1/artists/3mGW1eoqwNtCxd8R3hIOM5'},
#  {'artist_id': '63L8XYlQRWRGlg1d4ujXDc',
#   'artist_name': 'JANI',
#   'external_url': 'https://api.spotify.com/v1/artists/63L8XYlQRWRGlg1d4ujXDc'},
#  {'artist_id': '04ENOEpTQgKEVWrvlHwdzN',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id         name release_date  total_tracks  \
# 0  66sgvYGlzFD9QyMzHYFqRh  Open Letter   2023-02-18            15
# 1  1rbTFWa6pVztLGlJzW0ABx       Gumaan   2020-09-18             1
# 2  7bzGEQUHmMZOcz0DQdecAO       Anjaan   2021-09-03             1
# 3  49SibiaazOamj2Pf2bi0dA    Since Tum   2024-09-25             1
# 4  6gQbhFLkMM1b0dcYPz4PLL     Jawab De   2024-10-15             1
#
#                                                  url
# 0  https://open.spotify.com/album/66sgvYGlzFD9QyM...
# 1  https://open.spotify.com/album/1rbTFWa6pVztLGl...
# 2  https://open.spotify.com/album/7bzGEQUHmMZOcz0...
# 3  https://open.spotify.com/album/49SibiaazOamj2P...
# 4  https://open.spotify.com/album/6gQbhFLkMM1b0dc...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      15 non-null     object
#  1   name          15 non-null     object
#  2   release_date  15 non-null     object
#  3   total_tracks  15 non-null     int64
#  4   url           15 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 732.0+ bytes

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id        song_name  duration_ms  \
# 0  5yqr66QIdRvhh5cxjgpkJh  Downers at Dusk       256000
# 1  6cdiviyVL3tFYE1eDcmUzL           Gumaan       260173
# 2  34udZ2dsuJZaXmpmnIR2jy           Anjaan       303203
# 3  5GnF4uvEcIibqcoYgzIlgS        Since Tum       263181
# 4  5D0DPHvozDW5qDLK7SS83X         Jawab De       195929
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/5yqr66QIdRvhh5c...          70
# 1  https://open.spotify.com/track/6cdiviyVL3tFYE1...          67
# 2  https://open.spotify.com/track/34udZ2dsuJZaXmp...          49
# 3  https://open.spotify.com/track/5GnF4uvEcIibqco...          60
# 4  https://open.spotify.com/track/5D0DPHvozDW5qDL...          39
#
#              song_added                album_id               artist_id
# 0  2024-11-08T06:53:56Z  66sgvYGlzFD9QyMzHYFqRh  69xcFpmqTOmFNOL08Bxyci
# 1  2024-11-08T06:54:03Z  1rbTFWa6pVztLGlJzW0ABx  01PyusFVbXgoD5Kl1mR8CC
# ...

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  69xcFpmqTOmFNOL08Bxyci     Talha Anjum
# 1  1n6pjRJkTY5v8RtUCAv5pi           Umair
# 2  01PyusFVbXgoD5Kl1mR8CC  Young Stunners
# 4  3mGW1eoqwNtCxd8R3hIOM5    Talhah Yunus
# 5  63L8XYlQRWRGlg1d4ujXDc            JANI
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/69xcFpmqTOm...
# 1  https://api.spotify.com/v1/artists/1n6pjRJkTY5...
# 2  https://api.spotify.com/v1/artists/01PyusFVbXg...
# 4  https://api.spotify.com/v1/artists/3mGW1eoqwNt...
# 5  https://api.spotify.com/v1/artists/63L8XYlQRWR...

# %%
album_df.head()
# Out:
#                  album_id         name release_date  total_tracks  \
# 0  66sgvYGlzFD9QyMzHYFqRh  Open Letter   2023-02-18            15
# 1  1rbTFWa6pVztLGlJzW0ABx       Gumaan   2020-09-18             1
# 2  7bzGEQUHmMZOcz0DQdecAO       Anjaan   2021-09-03             1
# 3  49SibiaazOamj2Pf2bi0dA    Since Tum   2024-09-25             1
# 4  6gQbhFLkMM1b0dcYPz4PLL     Jawab De   2024-10-15             1
#
#                                                  url
# 0  https://open.spotify.com/album/66sgvYGlzFD9QyM...
# 1  https://open.spotify.com/album/1rbTFWa6pVztLGl...
# 2  https://open.spotify.com/album/7bzGEQUHmMZOcz0...
# 3  https://open.spotify.com/album/49SibiaazOamj2P...
# 4  https://open.spotify.com/album/6gQbhFLkMM1b0dc...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      15 non-null     object
#  1   song_name    15 non-null     object
#  2   duration_ms  15 non-null     int64
#  3   url          15 non-null     object
#  4   popularity   15 non-null     int64
#  5   song_added   15 non-null     datetime64[ns, UTC]
#  6   album_id     15 non-null     object
#  7   artist_id    15 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 1.1+ KB

# %%
# !python --version
# Out:
# Python 3.11.12
